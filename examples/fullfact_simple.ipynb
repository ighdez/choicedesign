# %% [markdown]
# # Example of a full-factorial design with ChoiceDesign
#
# This notebook illustrates how to use **ChoiceDesign** to generate a simple full-factorial experimental design.
#
# ## Step 1: Load modules, define design attributes
#
# The following lines load:
# - `FullFactDesign`: the class of full-factorial designs,
# - `Attribute`: the class of attributes.

# %%
from choicedesign.design import FullFactDesign
from choicedesign.expressions import Attribute
# Out:
# /Users/ignacio/Library/Caches/pypoetry/virtualenvs/choicedesign-oSBhddzi-py3.13/lib/python3.13/site-packages/pyDOE2/doe_factorial.py:201: SyntaxWarning: invalid escape sequence '\-'
#   A = [item for item in re.split('\-|\s|\+', gen) if item]  # remove empty strings
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from choicedesign.design import FullFactDesign
#       2 from choicedesign.expressions import Attribute
#
# File ~/software/choicedesign/choicedesign/design.py:10
#       8 from biogeme.expressions import MonteCarlo, log
#       9 from biogeme.models import loglogit, logit
# ---> 10 from pyDOE2 import fullfact
#      12 from choicedesign.expressions import Attribute
#      13 from choicedesign.algorithms import _swapalg
#
# File ~/Library/Caches/pypoetry/virtualenvs/choicedesign-oSBhddzi-py3.13/lib/python3.13/site-packages/pyDOE2/__init__.py:22
#       1 """
#       2 pyDOE original code was originally converted from code by the following
#       3 individuals for use with Scilab:
#    (...)     19 - Copyright (C) 2018 - Rickard Sjoegren and Daniel Svensson
#      20 """
# ---> 22 from pyDOE2.doe_box_behnken import *
#      23 from pyDOE2.doe_composite import *
#      24 from pyDOE2.doe_factorial import *
#
# File ~/Library/Caches/pypoetry/virtualenvs/choicedesign-oSBhddzi-py3.13/lib/python3.13/site-packages/pyDOE2/doe_box_behnken.py:17
#       1 """
#       2 This code was originally published by the following individuals for use with
#       3 Scilab:
#    (...)     13 Abraham Lee.
#      14 """
#      16 import numpy as np
# ---> 17 from pyDOE2.doe_factorial import ff2n
#      18 from pyDOE2.doe_repeat_center import repeat_center
#      20 __all__ = ['bbdesign']
#
# File ~/Library/Caches/pypoetry/virtualenvs/choicedesign-oSBhddzi-py3.13/lib/python3.13/site-packages/pyDOE2/doe_factorial.py:16
#       1 """
#       2 This code was originally published by the following individuals for use with
#       3 Scilab:
#    (...)     13 Abraham Lee.
#      14 """
# ---> 16 import imp
#      17 import itertools
#      18 import math
#
# ModuleNotFoundError: No module named 'imp'

# %% [markdown]
# Each attribute is defined by the `Attribute` class. The arguments of this class are:
#
# * `name`: a string with the attribute name,
# * `levels`: a list of levels of the attribute,
#
# Each attribute is alternative-specific. Hence, attributes must be defined for each alternative that contains them.
#
# The following lines define 2 alternatives, named `alt1` and `alt2`, and 3 attributes named from $A$ to $C$:

# %%
alt1_A = Attribute('alt1_A',[1,2,3])
alt1_B = Attribute('alt1_B',[10,15,15.5])

alt2_A = Attribute('alt2_A',[1,2,3])
alt2_C = Attribute('alt2_C',[0,3,5])

# %% [markdown]
# ## Step 2: Construct full-factorial design object and generate initial design matrix
#
# The second step consists of constructing the experimental design object, which requires the following parameters:
#
# - `X`: A list of `Attribute` class elements,
#
# The following lines define a object named `design` using `FullFactDesign`:

# %%
design = FullFactDesign(
    X = [alt1_A,alt1_B,
         alt2_A,alt2_C])

# %% [markdown]
# After the design object is defined, the method `gen_design()` generates the design matrix.

# %%
init_design = design.gen_design()
init_design
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 init_design = design.gen_design()
#       2 init_design
#
# File ~/software/choicedesign/choicedesign/design.py:316, in FullFactDesign.gen_design(self)
#     313 def gen_design(self):
#     314     # Generate default full-fact design
#     315     n_levels = [len(j) for j in self.levs]
# --> 316     init_design = fullfact(n_levels)
#     318     # Create pandas dataframe
#     319     init_design = pd.DataFrame(init_design.astype(int),columns=self.names)
#
# NameError: name 'fullfact' is not defined
